# %% [markdown]
# # Casos en El Salvador: Covid-19

# %%
import pandas as pd

# %%
casos_covid = pd.read_csv("C:/Users/Christian/Desktop/Datos - ML/datasets/Covid/owid-covid-data.csv")

# %%
casos_covid.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  6.595800e+04   65956.000000        64955.000000  5.715400e+04
# mean   5.199662e+05    5014.164822         5020.037343  1.639551e+04
# std    3.688184e+06   32174.126100        31872.813413  9.416307e+04
# min    1.000000e+00  -46076.000000        -1121.714000  1.000000e+00
# 25%    5.990000e+02       1.000000            5.143000  3.200000e+01
# 50%    6.347500e+03      53.000000           63.143000  2.035000e+02
# 75%    7.016075e+04     613.000000          636.000000  1.959750e+03
# max    1.043919e+08  858062.000000       738534.000000  2.268797e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  57312.000000         64955.000000             63005.000000
# mean     127.183906           110.236005              5986.796018
# std      700.909169           632.350209             12127.823796
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
if casos_covid == Asia
# Out:
#      iso_code      continent             location        date  total_cases  \
# 0         AFG           Asia          Afghanistan  2020-02-24          1.0
# 1         AFG           Asia          Afghanistan  2020-02-25          1.0
# 2         AFG           Asia          Afghanistan  2020-02-26          1.0
# 3         AFG           Asia          Afghanistan  2020-02-27          1.0
# 4         AFG           Asia          Afghanistan  2020-02-28          1.0
# ...       ...            ...                  ...         ...          ...
# 2295      ATG  North America  Antigua and Barbuda  2020-11-10        131.0
# 2296      ATG  North America  Antigua and Barbuda  2020-11-11        131.0
# 2297      ATG  North America  Antigua and Barbuda  2020-11-12        131.0
# 2298      ATG  North America  Antigua and Barbuda  2020-11-13        133.0
# 2299      ATG  North America  Antigua and Barbuda  2020-11-14        134.0
#
#       new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
if
